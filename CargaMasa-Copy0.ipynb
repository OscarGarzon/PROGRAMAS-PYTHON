# %%
# -*- coding: utf-8 -*-
# %pylab inline 
# %pylab --no-import-all
from matplotlib.pyplot import *
from numpy import *
# %matplotlib inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# Using matplotlib backend: TkAgg
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['draw_if_interactive', 'new_figure_manager']
# `%pylab --no-import-all` prevents importing * from pylab and numpy

# %%
y=[200,240,280,320,360,400]
x=[7.45,9.60,11.42,13.10,15.09,17.41]

# %%
fig, ax = subplots()
ylabel('$2U$ $[Volts]$')
xlabel('$(Br)^2 [Tcm]^2$')
err_y = 2
err_x = 0.98
errorbar(x, y, xerr=err_x, yerr=err_y, fmt='o')
plot
a=arange(6, 20,0.1)
b=a*20.56+46.17
xlim(5,20)
ylim(150,405)

plot(a, b)
ax.text(6, 340, r"$r^2=0.98$", fontsize=18, color="black")
ax.text(6, 380, r"$y=20.56x+46.17$", fontsize=18, color="black")
ax.legend(loc=2);

# %%
fig.savefig("regresion.png")
