# %%
# -*- coding: utf-8 -*-
# %pylab inline 
import numpy as np
# %pylab --no-import-all
from matplotlib.pyplot import *
from numpy import *
import math
from scipy import stats
# %matplotlib inline
figsize(15,10)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# Using matplotlib backend: TkAgg
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['draw_if_interactive', 'new_figure_manager']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
#Se importan datos
data = np.loadtxt("seno_theta_vs_u_inverso.txt")
U_INVERSO=data[:,0]
SEN_THETA= data[:,1]
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-82-f73636812993> in <module>()
#       1 #Se importan datos
# ----> 2 data = np.loadtxt("seno_theta_vs_u_inverso.txt")
#       3 U_INVERSO=data[:,0]
#       4 SEN_THETA= data[:,1]
#
# /usr/lib/python2.7/dist-packages/numpy/lib/npyio.pyc in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin)
#     801                 fh = iter(bz2.BZ2File(fname))
#     802             elif sys.version_info[0] == 2:
# --> 803                 fh = iter(open(fname, 'U'))
#     804             else:
#     805                 fh = iter(open(fname))
#
# IOError: [Errno 2] No such file or directory: 'seno_theta_vs_u_inverso.txt'

# %%
#Cálculo de incertidumbres
err_y=[]
err_x=[]
for i in range(len(SEN_THETA)):
    theta=0
    theta=math.asin(SEN_THETA[i])
    error_y= abs(cos(theta))*0.0174533
    err_y.append(error_y)
for i in range(len(U_INVERSO)):
    error_x=((U_INVERSO[i])**2)*(3)
    err_x.append(error_x)
err_y
# Out:
# [0.017364051253300341,
#  0.017357741202710133,
#  0.017337707899855549,
#  0.01731197569068664,
#  0.017291856512573422,
#  0.017257155025313074,
#  0.017223899796078045]

# %%
m, b, r_value, p_value, std_err = stats.linregress(U_INVERSO,SEN_THETA)
m,b,r_value**2,  std_err
# Out:
# (1.708396415736378,
#  0.033502829718222132,
#  0.98626403303603782,
#  0.090164726661323025)

# %%
fig, ax = subplots()
ylabel('$Sen(\Theta)$', fontsize=20)
xlabel('$1/U$ ($1/KV$)', fontsize=20)

for i in range(len(SEN_THETA)):
    errorbar(U_INVERSO[i], SEN_THETA[i], xerr=err_x[i], yerr=err_y[i],capsize=0 ,color="#6495ed",fmt='o')

x=arange(0.03, 0.1,0.001)
y=x*m+b

plot(x, y, color='k')
ax.text(0.025, 0.18, r"$r^2=0.98$", fontsize=18, color="black")
ax.text(0.025, 0.2, r"$y=1.7083x+0.0335$", fontsize=18, color="black")
ax.legend(loc=2);
ax.legend(loc=2);

# %%
fig.savefig("SEN_THETA_VS_U_INV.png")
